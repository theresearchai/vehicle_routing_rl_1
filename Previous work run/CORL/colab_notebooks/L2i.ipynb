# %%
# This ensures that a gpu is being used by the current google colab session.

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Oct 23 21:43:04 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# This code block is used to access your google drive

from google.colab import drive
ROOT = "/content/drive"
drive.mount(ROOT)
# Out:
# Mounted at /content/drive

# %%
# Make sure this points to the project folder

# %cd drive/'My Drive'/CORL
# Out:
# /content/drive/My Drive/CORL

# %%
# %cd l2i
# for l2i evo
#%cd l2i_evo
# Out:
# /content/drive/My Drive/CORL/l2i

# %%
# This line will run the l2i code with the below settings

# !python3 run.py --problem_seed 1000 --num_episode 500 --save_hrs 2 3 4 5 6 8 10 --max_rollout_steps 20000
# Out:
# usage: run.py [-h] [--name NAME] [--folder FOLDER] [--epoch_size EPOCH_SIZE]
#               [--num_training_points NUM_TRAINING_POINTS]
#               [--num_test_points NUM_TEST_POINTS] [--num_episode NUM_EPISODE]
#               [--num_paths_to_ruin NUM_PATHS_TO_RUIN]
#               [--batch_size BATCH_SIZE]
#               [--max_rollout_steps MAX_ROLLOUT_STEPS]
#               [--max_rollout_seconds MAX_ROLLOUT_SECONDS]
#               [--detect_negative_cycle [DETECT_NEGATIVE_CYCLE]]
#               [--epsilon_greedy EPSILON_GREEDY]
#               [--sample_actions_in_rollout [SAMPLE_ACTIONS_IN_ROLLOUT]]
#               [--max_no_improvement MAX_NO_IMPROVEMENT]
#               [--num_actions NUM_ACTIONS] [--problem_seed PROBLEM_SEED]
#               [--num_embedded_dim NUM_EMBEDDED_DIM]
#               [--discount_factor DISCOUNT_FACTOR]
#               [--policy_learning_rate POLICY_LEARNING_RATE]
#               [--hidden_layer_dim HIDDEN_LAYER_DIM]
# ...

# %%
# This takes attention model as initial then run L2I
# !python3 run.py --problem_seed 1000 --num_episode 250 --save_hrs 2 3 4 5  --max_rollout_steps 20000 --initial_solutions '../init_sols/att_5hr_init_sol.pickle' --folder '../models/att_to_l2i'
# Out:
# Sample #0 avg min dist: 15.441231634745007 time for samp: 211.9539601802826
# Sample #1 avg min dist: 14.738377685408246 time for samp: 223.77293300628662
# Sample #2 avg min dist: 14.619636234119511 time for samp: 205.9252028465271
# Sample #3 avg min dist: 14.358970641851915 time for samp: 238.78184127807617
# Sample #4 avg min dist: 14.956292005848024 time for samp: 208.48042011260986
# Sample #5 avg min dist: 15.121441139869491 time for samp: 229.7852065563202
# Sample #6 avg min dist: 15.329169177307946 time for samp: 211.9356234073639
# Sample #7 avg min dist: 15.353916730609892 time for samp: 228.89447116851807
# Sample #8 avg min dist: 15.387390124675782 time for samp: 218.15566611289978
# Sample #9 avg min dist: 15.235123622650871 time for samp: 226.57385969161987
# Sample #10 avg min dist: 15.182841642335552 time for samp: 214.4013533592224
# Sample #11 avg min dist: 15.092242301644488 time for samp: 244.95922231674194
# ...
