# %%
# This ensures that a gpu is being used by the current google colab session.

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Select the Runtime > "Change runtime type" menu to enable a GPU accelerator,
# and then re-execute this cell.

# %%
# This code block is used to access your google drive

from google.colab import drive
ROOT = "/content/drive"
drive.mount(ROOT)
# Out:
# Mounted at /content/drive

# %%
# Make sure this points to the project folder

# %cd drive/'My Drive'/CORL
# Out:
# /content/drive/My Drive/CORL

# %%
# %cd attention
# Out:
# /content/drive/My Drive/CORL/attention

# %%
# install dependencies
# !pip install tensorboard_logger
# Out:
# Collecting tensorboard_logger
#   Downloading https://files.pythonhosted.org/packages/87/7a/ec0fd26dba69191f82eb8f38f5b401c124f45a207490a7ade6ea9717ecdb/tensorboard_logger-0.1.0-py2.py3-none-any.whl
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard_logger) (1.4.1)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard_logger) (7.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboard_logger) (1.15.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from tensorboard_logger) (3.12.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboard_logger) (1.18.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->tensorboard_logger) (50.3.0)
# Installing collected packages: tensorboard-logger
# Successfully installed tensorboard-logger-0.1.0

# %%
# This block will run the originial attention code with the below settings
# The save_hrs are the checkpoint hours to save the model

#!python run.py --graph_size 100 --batch_size 64 --problem cvrp --baseline rollout --run_name 'vrp100_rollout' --save_hrs 5 10 --epoch_size 12800 --n_epochs 500

# this is an example of how to run evolution code
# !python vrp_evolve.py --save_dir ../models/att_evo --save_hrs 2 3 4 5 6 8 10 --sigma 0.001 --lr 0.000001 --dataset_size 12800 --epochs 500
# Out:
# Fitness started at 	89.26287841796875
# -------------------
# 100% 200/200 [16:18<00:00,  4.89s/it]
# Epoch 1/500 		39.53981018066406
# 100% 200/200 [15:37<00:00,  4.69s/it]
# Epoch 2/500 		38.02486801147461
# 100% 200/200 [15:41<00:00,  4.71s/it]
# Epoch 3/500 		34.227027893066406
# 100% 200/200 [15:33<00:00,  4.67s/it]
# Epoch 4/500 		34.0574951171875
# 100% 200/200 [15:36<00:00,  4.68s/it]
# Epoch 5/500 		32.734249114990234
# 100% 200/200 [15:15<00:00,  4.58s/it]
# Epoch 6/500 		31.337066650390625
# 100% 200/200 [15:14<00:00,  4.57s/it]
# Epoch 7/500 		30.164690017700195
# 100% 200/200 [15:08<00:00,  4.54s/it]
# Epoch 8/500 		29.979026794433594
# 100% 200/200 [15:15<00:00,  4.58s/it]
# Epoch 9/500 		30.76459503173828
# 100% 200/200 [15:23<00:00,  4.62s/it]
# Epoch 10/500 		29.63076400756836
# 100% 200/200 [15:19<00:00,  4.60s/it]
# Epoch 11/500 		30.164169311523438
# 100% 200/200 [15:11<00:00,  4.56s/it]
# Epoch 12/500 		29.011316299438477
# 100% 200/200 [15:30<00:00,  4.65s/it]
# Epoch 13/500 		30.384296417236328
# 100% 200/200 [15:26<00:00,  4.63s/it]
# Epoch 14/500 		30.131860733032227
# 100% 200/200 [15:47<00:00,  4.74s/it]
# Epoch 15/500 		28.747562408447266
# 100% 200/200 [15:18<00:00,  4.59s/it]
# Epoch 16/500 		28.76700782775879
# 100% 200/200 [15:12<00:00,  4.56s/it]
# Epoch 17/500 		28.869295120239258
# 100% 200/200 [15:13<00:00,  4.57s/it]
# Epoch 18/500 		28.43719482421875
# 100% 200/200 [15:17<00:00,  4.59s/it]
# Epoch 19/500 		28.076412200927734
# 100% 200/200 [15:07<00:00,  4.54s/it]
# Epoch 20/500 		28.352054595947266
# 100% 200/200 [15:15<00:00,  4.58s/it]
# Epoch 21/500 		29.0743408203125
# 100% 200/200 [15:13<00:00,  4.57s/it]
# Epoch 22/500 		28.586971282958984
# 100% 200/200 [15:17<00:00,  4.59s/it]
# Epoch 23/500 		28.28409194946289
# 100% 200/200 [15:12<00:00,  4.56s/it]
# Epoch 24/500 		28.45294761657715
# 100% 200/200 [15:22<00:00,  4.61s/it]
# Epoch 25/500 		28.322893142700195
# 100% 200/200 [15:24<00:00,  4.62s/it]
# Epoch 26/500 		28.495868682861328
# 100% 200/200 [15:23<00:00,  4.62s/it]
# Epoch 27/500 		28.184707641601562
# 100% 200/200 [15:24<00:00,  4.62s/it]
# Epoch 28/500 		28.43572998046875
# 100% 200/200 [15:22<00:00,  4.61s/it]
# Epoch 29/500 		28.544265747070312
# 100% 200/200 [14:57<00:00,  4.49s/it]
# Epoch 30/500 		28.3490047454834
# 100% 200/200 [14:54<00:00,  4.47s/it]
# Epoch 31/500 		28.68355369567871
# 100% 200/200 [15:02<00:00,  4.51s/it]
# Epoch 32/500 		28.22484588623047
# 100% 200/200 [15:09<00:00,  4.55s/it]
# Epoch 33/500 		28.436216354370117
# 100% 200/200 [15:10<00:00,  4.55s/it]
# Epoch 34/500 		28.095170974731445
# 100% 200/200 [14:57<00:00,  4.49s/it]
# Epoch 35/500 		27.967031478881836
# 100% 200/200 [15:02<00:00,  4.51s/it]
# Epoch 36/500 		28.760774612426758
# 100% 200/200 [15:03<00:00,  4.52s/it]
# Epoch 37/500 		27.99097442626953
# 100% 200/200 [15:04<00:00,  4.52s/it]
# Epoch 38/500 		27.910991668701172
# 100% 200/200 [14:55<00:00,  4.48s/it]
# Epoch 39/500 		28.019765853881836
#  21% 42/200 [03:14<12:11,  4.63s/it]Traceback (most recent call last):
#   File "vrp_evolve.py", line 109, in <module>
#     train(args.epochs, args.vis_iter, args.save_iter, args.sigma, args.lr, args.problem_size, args.batch_size, args.dataset_size, args.load_source, args.save_hrs, args.save_dir)
#   File "vrp_evolve.py", line 74, in train
#     cost[i] = fitness(batch, model, params + sigma * eps[i])
#   File "vrp_evolve.py", line 20, in fitness
#     length, _ = model(batch)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 722, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/drive/My Drive/CORL/attention/nets/attention_model.py", line 138, in forward
#     _log_p, pi = self._inner(input, embeddings)
#   File "/content/drive/My Drive/CORL/attention/nets/attention_model.py", line 253, in _inner
#     log_p, mask = self._get_log_p(fixed, state)
#   File "/content/drive/My Drive/CORL/attention/nets/attention_model.py", line 359, in _get_log_p
#     log_p, glimpse = self._one_to_many_logits(query, glimpse_K, glimpse_V, logit_K, mask)
#   File "/content/drive/My Drive/CORL/attention/nets/attention_model.py", line 461, in _one_to_many_logits
#     compatibility = torch.matmul(glimpse_Q, glimpse_K.transpose(-2, -1)) / math.sqrt(glimpse_Q.size(-1))
# KeyboardInterrupt
#  21% 42/200 [03:16<12:20,  4.68s/it]
